# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "02-Homework_04-Pandas_Instructions_HeroesOfPymoli_Resources_purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file_to_load)

# %%
df.head(6)
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
# 5            5        Yalae81   22   Male       81
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44
# 5                                  Dreamkiss   3.61

# %%
df.nunique()
# Out:
# Purchase ID    780
# SN             576
# Age             39
# Gender           3
# Item ID        183
# Item Name      179
# Price          145
# dtype: int64

# %%
# players 
#Total=len(df['SN'].unique())
#Total

Total={'Number of players':len(df['SN'].unique())}
df1 = pd.DataFrame((Total), index=[0])
df1
# Out:
#    Number of players
# 0                576

# %%
#Average Price 
avg_price=(df['Price'].mean())

# %%
#Number of unique items
unique_items=len(df['Item ID'].unique())

# %%
#Number of Purchases
num_purchases=len(df['Purchase ID'].unique())

# %%
#Toral Revenue
#Average Price 
total_revenue=(df['Price'].sum())

# %%
final_purchase_analysys = pd.DataFrame({"Number of Unique Items":[unique_items],
                           "Average Price":[avg_price], 
                           "Number of Purchases": [num_purchases], 
                           "Total Revenue": [total_revenue]})
final_purchase_analysys.style.format({'Average Price':"${:,.2f}",
                         'Total Revenue': '${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_a450c640_4b73_11e9_a2b6_a45e60e20ec1" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Number of Unique Items</th>
#         <th class="col_heading level0 col1" >Average Price</th>
#         <th class="col_heading level0 col2" >Number of Purchases</th>
#         <th class="col_heading level0 col3" >Total Revenue</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a450c640_4b73_11e9_a2b6_a45e60e20ec1level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_a450c640_4b73_11e9_a2b6_a45e60e20ec1row0_col0" class="data row0 col0" >183</td>
#         <td id="T_a450c640_4b73_11e9_a2b6_a45e60e20ec1row0_col1" class="data row0 col1" >$3.05</td>
#         <td id="T_a450c640_4b73_11e9_a2b6_a45e60e20ec1row0_col2" class="data row0 col2" >780</td>
#         <td id="T_a450c640_4b73_11e9_a2b6_a45e60e20ec1row0_col3" class="data row0 col3" >$2,379.77</td>
# ...

# %%
#Number of male
male = df.loc[df["Gender"] == "Male"]
(male['Gender'])
male=len(male['SN'].unique())
male
# Out:
# 484

# %%
#Number of female
female = df.loc[df["Gender"] == "Female"]
(female['Gender'])
female=len(female['SN'].unique())
female
# Out:
# 81

# %%
#Number of other gender
other = df.loc[df["Gender"] == "Other / Non-Disclosed"]
(other['Gender'])
other=len(other['SN'].unique())
other
# Out:
# 11

# %%
total_sex=male+female+other
total_sex
# Out:
# 576

# %%
#percentage male
(male/total_sex)*100
# Out:
# 84.02777777777779

# %%
#percentage female
(female/total_sex)*100
# Out:
# 14.0625

# %%
#percentage other
(other/total_sex)*100
# Out:
# 1.9097222222222223

# %%
bygender=df.groupby("Gender")

# %%
countgender=bygender.nunique()["SN"]

# %%
percentage_players= ((countgender) / (total_sex)) *100

# %%
Dender_demo_final = pd.DataFrame({"Percentage of Players": percentage_players, 
                                    "Total Count": countgender})
Dender_demo_final.sort_values(["Total Count"], ascending = False).style.format({"Percentage of Players":"{:.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_a467b936_4b73_11e9_a2b6_a45e60e20ec1" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Percentage of Players</th>
#         <th class="col_heading level0 col1" >Total Count</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Gender</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a467b936_4b73_11e9_a2b6_a45e60e20ec1level0_row0" class="row_heading level0 row0" >Male</th>
#         <td id="T_a467b936_4b73_11e9_a2b6_a45e60e20ec1row0_col0" class="data row0 col0" >84.03</td>
#         <td id="T_a467b936_4b73_11e9_a2b6_a45e60e20ec1row0_col1" class="data row0 col1" >484</td>
#     </tr>    <tr>
#         <th id="T_a467b936_4b73_11e9_a2b6_a45e60e20ec1level0_row1" class="row_heading level0 row1" >Female</th>
# ...

# %%
#Purchase count male
male = df.loc[df["Gender"] == "Male"]
len(male['Gender'])
# Out:
# 652

# %%
#Purchase count female
female = df.loc[df["Gender"] == "Female"]
len(female['Gender'])
# Out:
# 113

# %%
#Purchase count other
other = df.loc[df["Gender"] == "Other / Non-Disclosed"]
len(other['Gender'])
# Out:
# 15

# %%
#Average Purchase Price male
male = df.loc[df["Gender"] == "Male"]
(male["Price"]).sum()/len(male['Gender'])
# Out:
# 3.0178527607361967

# %%
#Average Purchase Price female
female = df.loc[df["Gender"] == "Female"]
(female["Price"]).sum()/len(female['Gender'])
# Out:
# 3.203008849557522

# %%
#Average Purchase Price other
other = df.loc[df["Gender"] == "Other / Non-Disclosed"]
(other["Price"]).sum()/len(other['Gender'])
# Out:
# 3.3459999999999996

# %%
#Total purchase value male
male = df.loc[df["Gender"] == "Male"]
(male["Price"]).sum()
# Out:
# 1967.64

# %%
#Total purchase value female
female = df.loc[df["Gender"] == "Female"]
(female["Price"]).sum()
# Out:
# 361.94

# %%
#Total purchase value other
other = df.loc[df["Gender"] == "Other / Non-Disclosed"]
(other["Price"]).sum()
# Out:
# 50.19

# %%
#Avg Total Purchase per Person Male 
(male["Price"]).sum()/len(male['SN'].unique())
# Out:
# 4.065371900826446

# %%
#Avg Total Purchase per Person Female 
(female["Price"]).sum()/len(female['SN'].unique())
# Out:
# 4.468395061728395

# %%
#Avg Total Purchase per Person Other 
(other["Price"]).sum()/len(other['SN'].unique())
# Out:
# 4.5627272727272725

# %%
gender_stats=df.groupby("Gender")

# %%
purchase_count = gender_stats["Purchase ID"].count()

# %%
avg_purchase_price = gender_stats["Price"].mean()

# %%
avg_purchase_total = gender_stats["Price"].sum()

# %%
avg_purchase_per_person = avg_purchase_total/gender_stats.nunique()["SN"]

# %%
gender_demographics = pd.DataFrame({"Purchase Count": purchase_count, 
                                    "Average Purchase Price": avg_purchase_price,
                                    "Average Purchase Value":avg_purchase_total,
                                    "Avg Purchase Total per Person": avg_purchase_per_person})
gender_demographics.style.format({"Average Purchase Value":"${:,.2f}",
                                  "Average Purchase Price":"${:,.2f}",
                                  "Avg Purchase Total per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_a48e47f4_4b73_11e9_a2b6_a45e60e20ec1" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Purchase Count</th>
#         <th class="col_heading level0 col1" >Average Purchase Price</th>
#         <th class="col_heading level0 col2" >Average Purchase Value</th>
#         <th class="col_heading level0 col3" >Avg Purchase Total per Person</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Gender</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a48e47f4_4b73_11e9_a2b6_a45e60e20ec1level0_row0" class="row_heading level0 row0" >Female</th>
#         <td id="T_a48e47f4_4b73_11e9_a2b6_a45e60e20ec1row0_col0" class="data row0 col0" >113</td>
# ...

# %%
# Bins of ages
age_bins = [0, 9.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10","15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
# sort age values into bins 
df["Age Group"] = pd.cut(df["Age"],age_bins, labels=group_names)
df
# Out:
#      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0          Lisim78   20                   Male      108
# 1              1      Lisovynya38   40                   Male      143
# 2              2       Ithergue48   24                   Male       92
# 3              3    Chamassasya86   24                   Male      100
# 4              4        Iskosia90   23                   Male      131
# 5              5          Yalae81   22                   Male       81
# 6              6        Itheria73   36                   Male      169
# 7              7      Iskjaskst81   20                   Male      162
# 8              8        Undjask33   22                   Male       21
# 9              9      Chanosian48   35  Other / Non-Disclosed      136
# 10            10        Inguron55   23                   Male       95
# 11            11     Haisrisuir60   23                   Male      162
# ...

# %%
#group age
age_grouped = df.groupby("Age Group")
age_grouped

# %%
count_age = age_grouped["SN"].nunique()
count_age
# Out:
# Age Group
# <10       17
# 15-19    129
# 20-24    258
# 25-29     77
# 30-34     52
# 35-39     31
# 40+       12
# Name: SN, dtype: int64

# %%
Totals=len(df['SN'].unique())
percentage_by_age=(count_age/Totals)*100

# %%
age_demographics = pd.DataFrame({"Total Count": count_age ,"Percentage of Players" :percentage_by_age})
age_demographics
# Out:
#            Total Count  Percentage of Players
# Age Group
# <10                 17               2.951389
# 15-19              129              22.395833
# 20-24              258              44.791667
# 25-29               77              13.368056
# 30-34               52               9.027778
# 35-39               31               5.381944
# 40+                 12               2.083333

# %%
purchase_count_age = age_grouped["Purchase ID"].count()

# %%
avg_purchase_price_age = age_grouped["Price"].mean()

# %%
total_purchase_value = age_grouped["Price"].sum()

# %%
avg_purchase_per_person_age = total_purchase_value/count_age

# %%
age_demo2 = pd.DataFrame({"Purchase Count": purchase_count_age,
                                 "Average Purchase Price": avg_purchase_price_age,
                                 "Total Purchase Value":total_purchase_value,
                                 "Average Purchase Total per Person": avg_purchase_per_person_age})
age_demo2.style.format({"Average Purchase Price":"${:,.2f}",
                               "Total Purchase Value":"${:,.2f}",
                               "Average Purchase Total per Person":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_a4a91ff2_4b73_11e9_a2b6_a45e60e20ec1" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Purchase Count</th>
#         <th class="col_heading level0 col1" >Average Purchase Price</th>
#         <th class="col_heading level0 col2" >Total Purchase Value</th>
#         <th class="col_heading level0 col3" >Average Purchase Total per Person</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Age Group</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a4a91ff2_4b73_11e9_a2b6_a45e60e20ec1level0_row0" class="row_heading level0 row0" ><10</th>
#         <td id="T_a4a91ff2_4b73_11e9_a2b6_a45e60e20ec1row0_col0" class="data row0 col0" >23</td>
# ...

# %%
spender= df.groupby("SN")
spender

# %%
count_spender= spender["Purchase ID"].count()

# %%
avg_price_spender= spender["Price"].mean()

# %%
purchase_total= spender["Price"].sum()

# %%
top_spenders = pd.DataFrame({"Purchase Count": count_spender,
                             "Average Purchase Price": avg_price_spender,
                             "Total Purchase Value":purchase_total})

# %%
final_spender=top_spenders.sort_values(["Total Purchase Value"], ascending=False).head()
final_spender.style.format({"Average Purchase Total":"${:,.2f}",
                                 "Average Purchase Price":"${:,.2f}", 
                                 "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_a4b3dc4e_4b73_11e9_a2b6_a45e60e20ec1" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Purchase Count</th>
#         <th class="col_heading level0 col1" >Average Purchase Price</th>
#         <th class="col_heading level0 col2" >Total Purchase Value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >SN</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a4b3dc4e_4b73_11e9_a2b6_a45e60e20ec1level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#         <td id="T_a4b3dc4e_4b73_11e9_a2b6_a45e60e20ec1row0_col0" class="data row0 col0" >5</td>
#         <td id="T_a4b3dc4e_4b73_11e9_a2b6_a45e60e20ec1row0_col1" class="data row0 col1" >$3.79</td>
# ...

# %%
items = df[["Item ID", "Item Name", "Price"]]

# %%
item_stats = items.groupby(["Item ID","Item Name"])

# %%
count_item = item_stats["Price"].count()

# %%
purchase_value = (item_stats["Price"].sum())

# %%
item_price = purchase_value/count_item

# %%
popular_items = pd.DataFrame({"Purchase Count": count_item, 
                                   "Item Price": item_price,
                                   "Total Purchase Value":purchase_value})

# %%
popular_items_final=popular_items.sort_values(["Purchase Count"], ascending=False).head()
popular_items_final.style.format({"Item Price":"${:,.2f}",
                                "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_a4c03ad4_4b73_11e9_a2b6_a45e60e20ec1" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Purchase Count</th>
#         <th class="col_heading level0 col1" >Item Price</th>
#         <th class="col_heading level0 col2" >Total Purchase Value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Item ID</th>
#         <th class="index_name level1" >Item Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a4c03ad4_4b73_11e9_a2b6_a45e60e20ec1level0_row0" class="row_heading level0 row0" >178</th>
#         <th id="T_a4c03ad4_4b73_11e9_a2b6_a45e60e20ec1level1_row0" class="row_heading level1 row0" >Oathbreaker, Last Hope of the Breaking Storm</th>
# ...

# %%
popular_items.sort_values(["Total Purchase Value"],ascending=False).head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 82      Nirvana                                             4.90
# 145     Fiery Glass Crusader                                4.58
# 92      Final Critic                                        4.88
# 103     Singed Scalpel                                      4.35
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %%
popular_items.style.format({"Item Price":"${:,.2f}",
                                "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_a89b0346_4b73_11e9_a2b6_a45e60e20ec1" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Purchase Count</th>
#         <th class="col_heading level0 col1" >Item Price</th>
#         <th class="col_heading level0 col2" >Total Purchase Value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Item ID</th>
#         <th class="index_name level1" >Item Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a89b0346_4b73_11e9_a2b6_a45e60e20ec1level0_row0" class="row_heading level0 row0" >0</th>
#         <th id="T_a89b0346_4b73_11e9_a2b6_a45e60e20ec1level1_row0" class="row_heading level1 row0" >Splinter</th>
#         <td id="T_a89b0346_4b73_11e9_a2b6_a45e60e20ec1row0_col0" class="data row0 col0" >4</td>
# ...
